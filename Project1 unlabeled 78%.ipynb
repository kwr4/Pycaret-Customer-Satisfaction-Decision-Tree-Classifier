# %%
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
import numpy as np
import xgboost as xgb
import pandas as pd
import pycaret
import plotly.express as px

# %%
df = pd.read_csv("ACME-HappinessSurvey2020 (1).csv")
df.head()
# Out:
#    Y  X1  X2  X3  X4  X5  X6
# 0  0   3   3   3   4   2   4
# 1  0   3   2   3   5   4   3
# 2  1   5   3   3   3   3   5
# 3  0   5   4   3   3   3   5
# 4  0   5   4   3   3   3   5

# %%
from pycaret.classification import *

s = setup(data=df, target = 'Y', feature_selection = False )
# Out:
# <style type="text/css">
# #T_b136f_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b136f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b136f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b136f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b136f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b136f_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_b136f_row0_col1" class="data row0 col1" >6392</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b136f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b136f_row1_col1" class="data row1 col1" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b136f_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_b136f_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b136f_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_b136f_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b136f_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_b136f_row4_col1" class="data row4 col1" >(126, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b136f_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_b136f_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b136f_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_b136f_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b136f_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_b136f_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b136f_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_b136f_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b136f_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_b136f_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b136f_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_b136f_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b136f_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_b136f_row11_col1" class="data row11 col1" >(88, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b136f_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_b136f_row12_col1" class="data row12 col1" >(38, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b136f_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_b136f_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b136f_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_b136f_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b136f_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_b136f_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b136f_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_b136f_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b136f_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_b136f_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b136f_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_b136f_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b136f_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_b136f_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b136f_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_b136f_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b136f_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_b136f_row21_col1" class="data row21 col1" >6e5d</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b136f_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_b136f_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_b136f_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_b136f_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_b136f_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_b136f_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_b136f_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_b136f_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_b136f_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_b136f_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_b136f_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_b136f_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_b136f_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_b136f_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_b136f_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_b136f_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b136f_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_b136f_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_b136f_row30_col1" class="data row30

# %%
df.head()
# Out:
#    Y  X1  X2  X3  X4  X5
# 0  0   3   3   3   4   2
# 1  0   3   2   3   5   4
# 2  1   5   3   3   3   3
# 3  0   5   4   3   3   3
# 4  0   5   4   3   3   3

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_16076 th {
#   text-align: left;
# }
# #T_16076_row0_col0, #T_16076_row0_col2, #T_16076_row0_col3, #T_16076_row1_col0, #T_16076_row1_col1, #T_16076_row1_col3, #T_16076_row1_col4, #T_16076_row1_col5, #T_16076_row1_col6, #T_16076_row1_col7, #T_16076_row2_col0, #T_16076_row2_col1, #T_16076_row2_col2, #T_16076_row2_col3, #T_16076_row2_col4, #T_16076_row2_col5, #T_16076_row2_col6, #T_16076_row2_col7, #T_16076_row3_col0, #T_16076_row3_col1, #T_16076_row3_col2, #T_16076_row3_col3, #T_16076_row3_col4, #T_16076_row3_col5, #T_16076_row3_col6, #T_16076_row3_col7, #T_16076_row4_col0, #T_16076_row4_col1, #T_16076_row4_col2, #T_16076_row4_col3, #T_16076_row4_col4, #T_16076_row4_col5, #T_16076_row4_col6, #T_16076_row4_col7, #T_16076_row5_col0, #T_16076_row5_col1, #T_16076_row5_col2, #T_16076_row5_col3, #T_16076_row5_col4, #T_16076_row5_col5, #T_16076_row5_col6, #T_16076_row5_col7, #T_16076_row6_col0, #T_16076_row6_col1, #T_16076_row6_col2, #T_16076_row6_col3, #T_16076_row6_col4, #T_16076_row6_col5, #T_16076_row6_col6, #T_16076_row6_col7, #T_16076_row7_col0, #T_16076_row7_col1, #T_16076_row7_col2, #T_16076_row7_col3, #T_16076_row7_col4, #T_16076_row7_col5, #T_16076_row7_col6, #T_16076_row7_col7, #T_16076_row8_col0, #T_16076_row8_col1, #T_16076_row8_col2, #T_16076_row8_col3, #T_16076_row8_col4, #T_16076_row8_col5, #T_16076_row8_col6, #T_16076_row8_col7, #T_16076_row9_col0, #T_16076_row9_col1, #T_16076_row9_col2, #T_16076_row9_col3, #T_16076_row9_col4, #T_16076_row9_col5, #T_16076_row9_col6, #T_16076_row9_col7, #T_16076_row10_col0, #T_16076_row10_col1, #T_16076_row10_col2, #T_16076_row10_col4, #T_16076_row10_col5, #T_16076_row10_col6, #T_16076_row10_col7, #T_16076_row11_col0, #T_16076_row11_col1, #T_16076_row11_col2, #T_16076_row11_col3, #T_16076_row11_col4, #T_16076_row11_col5, #T_16076_row11_col6, #T_16076_row11_col7, #T_16076_row12_col0, #T_16076_row12_col1, #T_16076_row12_col2, #T_16076_row12_col3, #T_16076_row12_col4, #T_16076_row12_col5, #T_16076_row12_col6, #T_16076_row12_col7, #T_16076_row13_col0, #T_16076_row13_col1, #T_16076_row13_col2, #T_16076_row13_col3, #T_16076_row13_col4, #T_16076_row13_col5, #T_16076_row13_col6, #T_16076_row13_col7, #T_16076_row14_col0, #T_16076_row14_col1, #T_16076_row14_col2, #T_16076_row14_col3, #T_16076_row14_col4, #T_16076_row14_col5, #T_16076_row14_col6, #T_16076_row14_col7 {
#   text-align: left;
# }
# #T_16076_row0_col1, #T_16076_row0_col4, #T_16076_row0_col5, #T_16076_row0_col6, #T_16076_row0_col7, #T_16076_row1_col2, #T_16076_row10_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_16076_row0_col8, #T_16076_row6_col8, #T_16076_row9_col8, #T_16076_row10_col8, #T_16076_row11_col8, #T_16076_row12_col8, #T_16076_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_16076_row1_col8, #T_16076_row2_col8, #T_16076_row3_col8, #T_16076_row4_col8, #T_16076_row5_col8, #T_16076_row7_col8, #T_16076_row8_col8, #T_16076_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_16076">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16076_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_16076_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_16076_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_16076_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_16076_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_16076_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_16076_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_16076_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_16076_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16076_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_16076_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_16076_row0_col1" class="data row0 col1" >0.7819</td>
#       <td id="T_16076_row0_col2" class="data row0 col2" >0.7700</td>
#       <td id="T_16076_row0_col3" class="data row0 col3" >0.8367</td>
#       <td id="T_16076_row0_col4" class="data row0 col4" >0.8508</td>
#       <td id="T_16076_row0_col5" class="data row0 col5" >0.8246</td>
#       <td id="T_16076_row0_col6" class="data row0 col6" >0.5077</td>
#       <td id="T_16076_row0_col7" class="data row0 col7" >0.5326</td>
#       <td id="T_16076_row0_col8" class="data row0 col8" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_16076_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_16076_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_16076_row1_col1" class="data row1 col1" >0.7500</td>
#       <td id="T_16076_row1_col2" class="data row1 col2" >0.7928</td>
#       <td id="T_16076_row1_col3" class="data row1 col3" >0.8433</td>
#       <td id="T_16076_row1_col4" class="data row1 col4" >0.7948</td>
#       <td id="T_16076_row1_col5" class="data row1 col5" >0.8089</td>
#       <td id="T_16076_row1_col6" class="data row1 col6" >0.4456</td>
#       <td id="T_16076_row1_col7" class="data row1 col7" >0.4711</td>
#       <td id="T_16076_row1_col8" class="data row1 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_16076_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_16076_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_16076_row2_col1" class="data row2 col1" >0.7375</td>
#       <td id="T_16076_row2_col2" class="data row2 col2" >0.7275</td>
#       <td id="T_16076_row2_col3" class="data row2 col3" >0.8733</td>
#       <td id="T_16076_row2_col4" class="data row2 col4" >0.7645</td>
#       <td id="T_16076_row2_col5" class="data row2 col5" >0.8100</td>
#       <td id="T_16076_row2_col6" class="data row2 col6" >0.3968</td>
#       <td id="T_16076_row2_col7" class="data row2 col7" >0.4081</td>
#       <td id="T_16076_row2_col8" class="data row2 col8" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_16076_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_16076_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_16076_row3_col1" class="data row3 col1" >0.7278</td>
#       <td id="T_16076_row3_col2" class="data row3 col2" >0.7633</td>
#       <td id="T_16076_row3_col3" class="data row3 col3" >0.8533</td>
#       <td id="T_16076_row3_col4" class="data row3 col4" >0.7830</td>
#       <td id="T_16076_row3_col5" class="data row3 col5" >0.8012</td>
#       <td id="T_16076_row3_col6" class="data row3 col6" >0.3603</td>
#       <td id="T_16076_row3_col7" class="data row3 col7" >0.3645</td>
#       <td id="T_16076_row3_col8" class="data row3 col8" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_16076_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_16076_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_16076_row4_col1" class="data row4 col1" >0.7264</td>
#       <td id="T_16076_row4_col2" class="data row4 col2" >0.7208</td>
#       <td id="T_16076_row4_col3" class="data row4 col3" >0.8733</td>
#       <td id="T_16076_row4_col4" class="data row4 col4" >0.7608</td>
#       <td id="T_16076_row4_col5" class="data row4 col5" >0.8000</td>
#       <td id="T_16076_row4_col6" class="data row4 col6" >0.3629</td>
#       <td id="T_16076_row4_col7" class="data row4 col7" >0.3874</td>
#       <td id="T_16076_row4_col8" class="data row4 col8" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_16076_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_16076_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_16076_row5_col1" class="data row5 col1" >0.7042</td>
#       <td id="T_16076_row5_col2" class="data row5 col2" >0.7089</td>
#       <td id="T_16076_row5_col3" class="data row5 col3" >0.8000</td>
#       <td id="T_16076_row5_col4" class="data row5 col4" >0.7624</td>
#       <td

# %%
from sklearn.model_selection import GridSearchCV
